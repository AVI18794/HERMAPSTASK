# %% [markdown]
# ## How to use the SegmentationDataset

# %% [markdown]
# #### Load the required Classes

# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\miniconda\envs\deeplabfinetuning\lib\site-packages (8.2.0)

# %%
from segdataset import SegmentationDataset
from torch.utils.data import DataLoader
from torchvision import transforms

# %% [markdown]
# #### Create the dataset and dataloader followed by the creation of a sample batch

# %%
seg_dataset = SegmentationDataset("LaneData", "Images", "Masks", transforms=transforms.Compose([transforms.ToTensor()]))
seg_dataloader = DataLoader(seg_dataset, batch_size=32, shuffle=False, num_workers=8)
samples = next(iter(seg_dataloader))
# Display the image and mask tensor shape
# We see the tensor size is correct bxcxhxw, where b is batch size, c is number of channels, h is height, w is width
display(samples['image'].shape,
samples['mask'].shape)
# Out:
# C:\Miniconda\envs\deeplabfinetuning\lib\site-packages\torch\utils\data\dataloader.py:477: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4 (`cpuset` is not taken into account), which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Exception ignored in: <bound method _MultiProcessingDataLoaderIter.__del__ of <torch.utils.data.dataloader._MultiProcessingDataLoaderIter object at 0x0000019A97772208>>
# Traceback (most recent call last):
#   File "C:\Miniconda\envs\deeplabfinetuning\lib\site-packages\torch\utils\data\dataloader.py", line 1324, in __del__
#     self._shutdown_workers()
#   File "C:\Miniconda\envs\deeplabfinetuning\lib\site-packages\torch\utils\data\dataloader.py", line 1321, in _shutdown_workers
#     w.terminate()
#   File "C:\Miniconda\envs\deeplabfinetuning\lib\multiprocessing\process.py", line 116, in terminate
#     self._popen.terminate()
#   File "C:\Miniconda\envs\deeplabfinetuning\lib\multiprocessing\popen_spawn_win32.py", line 95, in terminate
#     _winapi.TerminateProcess(int(self._handle), TERMINATE)
# PermissionError: [WinError 5] Access is denied
# torch.Size([32, 3, 720, 1280])
# torch.Size([32, 1, 720, 1280])

# %% [markdown]
# #### Create a sample image and mask pair

# %%
img = transforms.ToPILImage()(samples['image'][5])
mask = transforms.ToPILImage()(samples['mask'][5])

# %% [markdown]
# #### Check whether the image and mask pairs are correct

# %%
display(img, mask)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x19AA1CB7860>
# <PIL.Image.Image image mode=L size=1280x720 at 0x19AA1CB7978>
